# %% [markdown]
# # Data Preprocessing Notebook 1
# ## Purpose of this NoteBook
#  - Data Preprocessing
#  - Running scripts to fetch data from datasets
#  - This notebook will be using scripts to fetch the videos used in the DOLOS website dataset
#
# > First script will download these videos

# %% [markdown]
# ## First gonnna query and get all the urls from the spreadsheet using pandas

# %%
import pandas as pd
import numpy as np

df = pd.read_excel('../data/spreadsheets/Dolos.xlsx', skiprows=2)
columns_to_drop = [num for num in range(8, len(df.columns))]
df.drop(df.columns[columns_to_drop], axis=1, inplace=True)

video_directory = './data/WebScrapedVideos/'

df['Video Path'] = video_directory
display(df.columns)
display(df.head())


url_list = df['Video URL'].to_list()
for i in range (10):
    print(url_list[i])
# Out:
# Index(['Video URL', 'File name of the video clip ',
#        'Label "truth" or "deception"', 'Start time in the episode',
#        'End time in the episode', 'Name of the game show', 'Participants name',
#        'Participants gender', 'Video Path'],
#       dtype='object')
#                                            Video URL  \
# 0  https://www.youtube.com/watch?v=UCPIBQDI0QM&li...
# 1  https://www.youtube.com/watch?v=UCPIBQDI0QM&li...
# 2  https://www.youtube.com/watch?v=UCPIBQDI0QM&li...
# 3  https://www.youtube.com/watch?v=UCPIBQDI0QM&li...
# 4  https://www.youtube.com/watch?v=UCPIBQDI0QM&li...
#
#   File name of the video clip  Label "truth" or "deception"  \
# 0         AN_WILTY_EP15_truth1                        truth
# 1         AN_WILTY_EP15_truth2                        truth
# 2         AN_WILTY_EP15_truth3                        truth
# 3           AN_WILTY_EP15_lie4                    deception
# 4           AN_WILTY_EP15_lie5                    deception
#
# ...

# %%
from __future__ import unicode_literals
import yt_dlp
import os

url = "https://www.youtube.com/watch?v=jNQXAC9IVRw"

ydl_opts = {}
with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download([url])
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=jNQXAC9IVRw
# [youtube] jNQXAC9IVRw: Downloading webpage
# [youtube] jNQXAC9IVRw: Downloading android sdkless player API JSON
# [youtube] jNQXAC9IVRw: Downloading tv client config
# [youtube] jNQXAC9IVRw: Downloading player ef5f17ca-main
# [youtube] jNQXAC9IVRw: Downloading tv player API JSON
# [youtube] jNQXAC9IVRw: Downloading web safari player API JSON
# WARNING: [youtube] Falling back to generic n function search
#          player = https://www.youtube.com/s/player/ef5f17ca/player_ias.vflset/en_US/base.js
# WARNING: [youtube] jNQXAC9IVRw: nsig extraction failed: Some formats may be missing
#          n = 8G1XctJf2DBWKPnr ; player = https://www.youtube.com/s/player/ef5f17ca/player_ias.vflset/en_US/base.js
#          Please report this issue on  https://github.com/yt-dlp/yt-dlp/issues?q= , filling out the appropriate issue template. Confirm you are on the latest version using  yt-dlp -U
# ...
